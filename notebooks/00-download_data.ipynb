# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/heart_statlog_cleveland_hungary_final.csv")
df.head()
# Out:
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
# 3   48    0                4           138          214                    0
# 4   54    1                3           150          195                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0
# 3            0             108                1      1.5         2       1
# 4            0             122                0      0.0         1       0

# %%
dicionario = pd.DataFrame({
    "Variável": [
        "Age", "Sex", "Chest Pain Type", "Resting BP S", "Cholesterol", 
        "Fasting Blood Sugar", "Resting ECG", "Max Heart Rate", 
        "Exercise Angina", "Oldpeak", "ST Slope", "Target"
    ],
    "Descrição": [
        "Idade em anos.",
        "Gênero (1 = Masculino, 0 = Feminino).",
        "Tipo de dor no peito (1 = Angina típica, 2 = Angina atípica, 3 = Dor não anginosa, 4 = Assintomático).",
        "Pressão arterial em repouso em mm Hg.",
        "Colesterol sérico em mg/dl.",
        "Açúcar no sangue em jejum > 120 mg/dl (1 = Verdadeiro; 0 = Falso).",
        "Resultados do eletrocardiograma em repouso (0 = Normal, 1 = Anormalidade da onda ST-T, 2 = Hipertrofia ventricular esquerda).",
        "Frequência cardíaca máxima alcançada.",
        "Angina induzida por exercício (1 = Sim, 0 = Não).",
        "Depressão do segmento ST induzida por exercício em relação ao repouso.",
        "Inclinação do segmento ST durante o pico do exercício (1 = Inclinada para Cima, 2 = Plana, 3 = Inclinada para Baixo).",
        "Diagnóstico de doença cardíaca (1 = Doença presente, 0 = Ausente)."
    ],
    "Tipo": [
        "Quantitativa", "Qualitativa", "Qualitativa", "Quantitativa", "Quantitativa", 
        "Qualitativa", "Qualitativa", "Quantitativa", 
        "Qualitativa", "Quantitativa", "Qualitativa", "Qualitativa"
    ],
    "Subtipo": [
        "Contínua", "Nominal", "Ordinal", "Contínua", "Contínua", 
        "Nominal", "Ordinal", "Contínua", 
        "Nominal", "Contínua", "Ordinal", "Nominal"
    ]
})

dicionario.to_csv('../data/external/dictionary.csv', index=False)
